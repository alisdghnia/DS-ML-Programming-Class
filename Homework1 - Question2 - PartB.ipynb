# %%
import numpy as np
m = 50 # number of data points
x = 6 * np.random.rand(m,1) - 3
y = 3*(x**2) + 5*x + 2*np.random.randn(m,1)

# %%
print(type(x), x.ndim, x.shape, type(y),y.ndim, y.shape)
print(x[:3])
print(y[:3])
# Out:
# <class 'numpy.ndarray'> 2 (50, 1) <class 'numpy.ndarray'> 2 (50, 1)
# [[-1.9779908 ]
#  [ 0.21553408]
#  [-2.66095704]]
# [[-1.63427869]
#  [ 1.95124637]
#  [11.25449868]]

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (40, 1) (40, 1) (10, 1) (10, 1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
print(lin_reg.intercept_, lin_reg.coef_)
# Out:
# [9.78186759] [[3.72736027]]

# %%
#this block of code plots the predicted values as a red line
#and the actual values as a scatter plot, along with the 
#mean squared error
# re-use this as needed 

y_predict = lin_reg.predict(x_test)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_predict)
print("Mean Squared Error on Test: ", mse)

order = x_test[:,0].argsort()
xs = x_test[order]
ys = y_predict[order]
plt.plot(xs,ys,"r-")
plt.scatter(x_test, y_test, color='blue')
plt.show()
# Out:
# Mean Squared Error on Test:  98.16430249262929

# %%
# let's add polynomial features of degree num_degrees (modify this and play around
# with this block of code and the next. what do you find?

from sklearn.preprocessing import PolynomialFeatures
num_degrees = 2
poly_features = PolynomialFeatures(degree=num_degrees, include_bias=False)
x_poly = poly_features.fit_transform(x)
print(x[0], x_poly[0])
print(x.shape, x_poly.shape)
# Out:
# [-1.9779908] [-1.9779908  3.9124476]
# (50, 1) (50, 2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
print(lin_reg.intercept_, lin_reg.coef_)
y_predict = lin_reg.predict(x_test)
mse = mean_squared_error(y_test,y_predict)
print("Mean Squared Error on Test: ", mse)

order = x_test[:,0].argsort()
x_test = x_test[order]
ys = y_predict[order]
truey = y_test[order]
xs = x_test[:,:-(num_degrees-1)]

plt.plot(xs,ys,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# [-0.10630572] [[4.61880182 3.0476031 ]]
# Mean Squared Error on Test:  2.467278780761326

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.5)
lasso_reg.fit(x_train, y_train)
y_predict = lasso_reg.predict(x_test)
mse = mean_squared_error(truey,y_predict)
print("Mean Squared Error on Test: ", mse)
print(lasso_reg.intercept_, lasso_reg.coef_)

plt.plot(xs,y_predict,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# Mean Squared Error on Test:  2.841947091041591
# [0.14666526] [4.46558517 2.97842619]

# %%
import numpy as np
m = 50 # number of data points
x = 6 * np.random.rand(m,1) - 3
y = 4*(x**2) + 3*x + 2 + 5*np.random.randn(m,1)
# let's add polynomial features of degree num_degrees (modify this and play around
# with this block of code and the next. what do you find?

from sklearn.preprocessing import PolynomialFeatures
num_degrees = 2
poly_features = PolynomialFeatures(degree=num_degrees, include_bias=False)
x_poly = poly_features.fit_transform(x)
print(x[0], x_poly[0])
print(x.shape, x_poly.shape)
# Out:
# [2.3248986] [2.3248986  5.40515348]
# (50, 1) (50, 2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
print(lin_reg.intercept_, lin_reg.coef_)
y_predict = lin_reg.predict(x_test)
mse = mean_squared_error(y_test,y_predict)
print("Mean Squared Error on Test: ", mse)

order = x_test[:,0].argsort()
x_test = x_test[order]
ys = y_predict[order]
truey = y_test[order]
xs = x_test[:,:-(num_degrees-1)]

plt.plot(xs,ys,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# [1.9999213] [[3.84688421 3.62351758]]
# Mean Squared Error on Test:  13.28869485618194

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.5)
lasso_reg.fit(x_train, y_train)
y_predict = lasso_reg.predict(x_test)
mse = mean_squared_error(truey,y_predict)
print("Mean Squared Error on Test: ", mse)
print(lasso_reg.intercept_, lasso_reg.coef_)

plt.plot(xs,y_predict,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# Mean Squared Error on Test:  12.641795183736633
# [2.24652796] [3.64153971 3.56230949]

# %%
import numpy as np
m = 50 # number of data points
x = 6 * np.random.rand(m,1) - 3
y = 4*(x**2) + 3*x + 2 + 10*np.random.randn(m,1)
# let's add polynomial features of degree num_degrees (modify this and play around
# with this block of code and the next. what do you find?

from sklearn.preprocessing import PolynomialFeatures
num_degrees = 2
poly_features = PolynomialFeatures(degree=num_degrees, include_bias=False)
x_poly = poly_features.fit_transform(x)
print(x[0], x_poly[0])
print(x.shape, x_poly.shape)
# Out:
# [-2.1862794] [-2.1862794   4.77981761]
# (50, 1) (50, 2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
print(lin_reg.intercept_, lin_reg.coef_)
y_predict = lin_reg.predict(x_test)
mse = mean_squared_error(y_test,y_predict)
print("Mean Squared Error on Test: ", mse)

order = x_test[:,0].argsort()
x_test = x_test[order]
ys = y_predict[order]
truey = y_test[order]
xs = x_test[:,:-(num_degrees-1)]

plt.plot(xs,ys,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# [3.50026532] [[3.46813372 3.84505696]]
# Mean Squared Error on Test:  51.25790262098904

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.5)
lasso_reg.fit(x_train, y_train)
y_predict = lasso_reg.predict(x_test)
mse = mean_squared_error(truey,y_predict)
print("Mean Squared Error on Test: ", mse)
print(lasso_reg.intercept_, lasso_reg.coef_)

plt.plot(xs,y_predict,"r-")
plt.scatter(xs, truey, color='blue')
plt.show()
# Out:
# Mean Squared Error on Test:  53.78006448746752
# [3.70679876] [3.31201916 3.77664652]

# %% [markdown]
# Question 2:
#
#         As the noise increases the regularized regression model's mean squared error starts doing much better than the unregularized linear regression.
